# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# import all datasets

SHC_1980_1984_df = pd.read_csv('data/SHC_1980_1984.csv')
SHC_1985_1989_df = pd.read_csv('data/SHC_1985_1989.csv')
SHC_1990_1994_df = pd.read_csv('data/SHC_1990_1994.csv')
SHC_1995_1999_df = pd.read_csv('data/SHC_1995_1999.csv')
SHC_2000_2004_df = pd.read_csv('data/SHC_2000_2004.csv')
SHC_2005_2009_df = pd.read_csv('data/SHC_2005_2009.csv')
SHC_2010_2014_df = pd.read_csv('data/SHC_2010_2014.csv')
SHC_2015_2019_df = pd.read_csv('data/SHC_2015_2019.csv')

# %%
#SHC_1980_1984_df.head(5)
SHC_2015_2019_df.head(5)
# Out:
#   Classification  Year  Period  Period Desc.  Aggregate Level  Is Leaf Code  \
# 0             H5  2017    2017          2017                4             0
# 1             H5  2017    2017          2017                4             0
# 2             H5  2017    2017          2017                4             0
# 3             H5  2017    2017          2017                4             0
# 4             H5  2017    2017          2017                4             0
#
#    Trade Flow Code Trade Flow  Reporter Code Reporter  ...      Qty  \
# 0                1     Import              8  Albania  ...  9948044
# 1                2     Export              8  Albania  ...    29067
# 2                1     Import             12  Algeria  ...      538
# 3                1     Import             20  Andorra  ...   391415
# 4                2     Export             20  Andorra  ...   338211
#
#    Alt Qty Unit Code Alt Qty Unit Alt Qty  Netweight (kg)  Gross weight (kg)  \
# 0                NaN          NaN     NaN       9948044.0                NaN
# 1                NaN          NaN     NaN         29067.0                NaN
# 2                NaN          NaN     NaN           538.0                NaN
# 3                NaN          NaN     NaN        391415.0                NaN
# 4                NaN          NaN     NaN        338211.0                NaN
#
#    Trade Value (US$)  CIF Trade Value (US$)  FOB Trade Value (US$)  Flag
# 0           10405997                    NaN                    NaN     0
# 1               9197                    NaN                    NaN     0
# 2               5038                    NaN                    NaN     0
# 3             843352                    NaN                    NaN     0
# 4             555746                    NaN                    NaN     0
#
# [5 rows x 35 columns]

# %%
print(SHC_1980_1984_df.columns)
print(SHC_2015_2019_df.columns)
# Out:
# Index(['Classification', 'Year', 'Period', 'Period Desc.', 'Aggregate Level',
#        'Is Leaf Code', 'Trade Flow Code', 'Trade Flow', 'Reporter Code',
#        'Reporter', 'Reporter ISO', 'Partner Code', 'Partner', 'Partner ISO',
#        '2nd Partner Code', '2nd Partner', '2nd Partner ISO',
#        'Customs Proc. Code', 'Customs', 'Mode of Transport Code',
#        'Mode of Transport', 'Commodity Code', 'Commodity', 'Qty Unit Code',
#        'Qty Unit', 'Qty', 'Alt Qty Unit Code', 'Alt Qty Unit', 'Alt Qty',
#        'Netweight (kg)', 'Gross weight (kg)', 'Trade Value (US$)',
#        'CIF Trade Value (US$)', 'FOB Trade Value (US$)', 'Flag'],
#       dtype='object')
# Index(['Classification', 'Year', 'Period', 'Period Desc.', 'Aggregate Level',
#        'Is Leaf Code', 'Trade Flow Code', 'Trade Flow', 'Reporter Code',
#        'Reporter', 'Reporter ISO', 'Partner Code', 'Partner', 'Partner ISO',
#        '2nd Partner Code', '2nd Partner', '2nd Partner ISO',
#        'Customs Proc. Code', 'Customs', 'Mode of Transport Code',
#        'Mode of Transport', 'Commodity Code', 'Commodity', 'Qty Unit Code',
#        'Qty Unit', 'Qty', 'Alt Qty Unit Code', 'Alt Qty Unit', 'Alt Qty',
#        'Netweight (kg)', 'Gross weight (kg)', 'Trade Value (US$)',
#        'CIF Trade Value (US$)', 'FOB Trade Value (US$)', 'Flag'],
#       dtype='object')

# %% [markdown]
# ## get rid of all the useless columns

# %%
def prep_SHC_df(df, netweight=True, CIF=False):
    df_ = pd.DataFrame()
    df_['Year'] = df['Year']
    df_['Trade Flow'] = df['Trade Flow']
    df_['Reporter'] = df['Reporter']
    df_['Partner'] = df['Partner']
    df_['Commodity'] = df['Commodity']
    if netweight:
        df_['Weight (kg)'] = df['Netweight (kg)']
    else:
        df_['Weight (kg)'] = df['Gross weight (kg)']
        
    if CIF:
        df_['Trade Value (US$)'] = df['CIF Trade Value (US$)']
    else:
        df_['Trade Value (US$)'] = df['Trade Value (US$)']
    
    return(df_)

# %%
SHC_1985_1989_small_df = prep_SHC_df(SHC_1985_1989_df, netweight=True, CIF=False)
SHC_1990_1994_small_df = prep_SHC_df(SHC_1990_1994_df, netweight=True, CIF=False)
SHC_1995_1999_small_df = prep_SHC_df(SHC_1995_1999_df, netweight=True, CIF=False)
SHC_2000_2004_small_df = prep_SHC_df(SHC_2000_2004_df, netweight=True, CIF=False)
SHC_2005_2009_small_df = prep_SHC_df(SHC_2005_2009_df, netweight=True, CIF=False)
SHC_2010_2014_small_df = prep_SHC_df(SHC_2010_2014_df, netweight=True, CIF=False)
SHC_2015_2019_small_df = prep_SHC_df(SHC_2015_2019_df, netweight=True, CIF=False)

# %%
# for some reason it doesn't matter if you differentiate between the different types ...

#SHC_1985_1989_small_df.head(5)
#SHC_1990_1994_small_df.head(5)
#SHC_1995_1999_small_df.head(5)
#SHC_2000_2004_small_df.head(5)
#SHC_2005_2009_small_df.head(5)
#SHC_2010_2014_small_df.head(5)
SHC_2015_2019_small_df.head(5)
# Out:
#    Year Trade Flow Reporter Partner  \
# 0  2017     Import  Albania   World
# 1  2017     Export  Albania   World
# 2  2017     Import  Algeria   World
# 3  2017     Import  Andorra   World
# 4  2017     Export  Andorra   World
#
#                                          Commodity  Weight (kg)  \
# 0  Textiles; worn clothing and other worn articles    9948044.0
# 1  Textiles; worn clothing and other worn articles      29067.0
# 2  Textiles; worn clothing and other worn articles        538.0
# 3  Textiles; worn clothing and other worn articles     391415.0
# 4  Textiles; worn clothing and other worn articles     338211.0
#
#    Trade Value (US$)
# 0           10405997
# 1               9197
# 2               5038
# 3             843352
# 4             555746

# %%
# append all DataFrames to one 

SHC_small_df = pd.concat([SHC_1985_1989_small_df, SHC_1990_1994_small_df, SHC_1995_1999_small_df, 
                          SHC_2000_2004_small_df, SHC_2005_2009_small_df, SHC_2010_2014_small_df,
                          SHC_2015_2019_small_df])

# Mozambique 2017 has to be a mistake in the data
SHC_small_df.at[975, 'Weight (kg)'] = 0

SHC_small_df.sort_values(['Year'])
# Out:
#      Year Trade Flow     Reporter Partner  \
# 0    1988     Import    Australia   World
# 20   1988     Import     Thailand   World
# 19   1988     Export  Switzerland   World
# 18   1988     Import  Switzerland   World
# 17   1988     Export        India   World
# ..    ...        ...          ...     ...
# 461  2019     Export      Iceland   World
# 462  2019     Import    Indonesia   World
# 463  2019     Export    Indonesia   World
# 465  2019     Export      Ireland   World
# 432  2019     Import       Cyprus   World
#
#                                            Commodity  Weight (kg)  \
# 0              Worn clothing and other worn articles          0.0
# 20             Worn clothing and other worn articles     270351.0
# 19             Worn clothing and other worn articles    2021673.0
# 18             Worn clothing and other worn articles     726745.0
# 17             Worn clothing and other worn articles       1678.0
# ..                                               ...          ...
# 461  Textiles; worn clothing and other worn articles    1811301.0
# 462  Textiles; worn clothing and other worn articles    4218761.0
# 463  Textiles; worn clothing and other worn articles    1563931.0
# 465  Textiles; worn clothing and other worn articles   12008474.0
# 432  Textiles; worn clothing and other worn articles      15661.0
#
#      Trade Value (US$)
# 0               898351
# 20             1182573
# 19             1509871
# 18              486941
# 17               13304
# ..                 ...
# 461             641679
# 462            6075437
# 463            1753793
# 465           10040969
# 432              52738
#
# [7541 rows x 7 columns]

# %%
# group by year and trade flow

SHC_small_grouped_df = SHC_small_df.groupby(['Year', 'Trade Flow'], as_index=False).sum()
SHC_small_grouped_df
# Out:
#     Year Trade Flow   Weight (kg)  Trade Value (US$)
# 0   1988     Export  1.432056e+08           91027262
# 1   1988     Import  8.736052e+06           13669223
# 2   1989     Export  1.879825e+08          126681439
# 3   1989     Import  5.449574e+07           73905400
# 4   1990     Export  2.070919e+08          157102605
# ..   ...        ...           ...                ...
# 59  2017     Import  3.524668e+09         3411250963
# 60  2018     Export  3.549123e+09         4407491195
# 61  2018     Import  4.101217e+09         3416360644
# 62  2019     Export  2.855532e+09         3891636500
# 63  2019     Import  2.970920e+09         2363310203
#
# [64 rows x 4 columns]

# %%
SHC_small_grouped_export_df = SHC_small_grouped_df[SHC_small_grouped_df['Trade Flow'] == 'Export']
SHC_small_grouped_import_df = SHC_small_grouped_df[SHC_small_grouped_df['Trade Flow'] == 'Import']

years = SHC_small_grouped_export_df['Year']

# %% [markdown]
# # Do some plotting

# %%
plt.plot(years, SHC_small_grouped_export_df['Weight (kg)'])

# %%
plt.plot(years, SHC_small_grouped_export_df['Trade Value (US$)'])

# %%
pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', None)

#SHC_small_df[(SHC_small_df['Year'] == 2017) & (SHC_small_df['Trade Flow'] == 'Import')]

plt.plot(years, SHC_small_grouped_import_df['Weight (kg)']);

# %%
plt.plot(years, SHC_small_grouped_import_df['Trade Value (US$)'])

# %% [markdown]
# ## look at proportion that Africa had as importer and West as exporter over that time

# %%
#print(SHC_small_df['Reporter'].unique())

#we use africa as subsaharan africa here.
african_countries = ['Madagascar', 'Malawi','Kenya', 'So. African Customs Union', 'Burundi', 'Central African Rep.', 
                    'Gabon', 'Congo', 'Mozambique', 'Togo', 'Uganda', 'Gambia', 'Senegal', 'United Rep. of Tanzania',
                    'Zambia', 'Benin', 'Guinea', 'Mali', 'Niger', 'Nigeria', 'Fmr Sudan', 'Cameroon', 'Chad', 
                    'Ethiopia', "Côte d'Ivoire", 'Zimbabwe', 'Burkina Faso', 'Ghana',  'Rwanda', 
                    'South Africa', 'Namibia', 'Botswana', 'Eswatini', 'Dominican Rep.', 'Lesotho', 'Sierra Leone',                      
                    'Angola', 'Djibouti', 'Sudan']

western_countries = ['Australia', 'Finland', 'Fmr Fed. Rep. of Germany', 'Greece', 'Iceland',
                     'Portugal', 'Switzerland' , 'Canada', 'Denmark', 'New Zealand', 'Spain', 
                     'Germany', 'USA', 'Croatia', 'Hungary', 'Ireland', 'Rep. of Korea', 'Japan',
                     'Netherlands', 'Sweden', 'Czechia', 'Norway', 'United Kingdom', 'Austria',
                     'France', 'Italy', 'Poland', 'Belgium-Luxembourg', 'Bulgaria', 'Estonia',
                     'Israel', 'Belgium', 'Luxembourg', 'Bosnia Herzegovina', 'Serbia']

SHC_small_df['Region'] = np.where(SHC_small_df['Reporter'].isin(african_countries), 'Africa', 'Rest')
SHC_small_df['Region'] = np.where(SHC_small_df['Reporter'].isin(western_countries), 'West', SHC_small_df['Region'])
SHC_small_df.head(100)
# Out:
#     Year Trade Flow                  Reporter Partner  \
# 0   1988     Import                 Australia   World
# 1   1988     Export                 Australia   World
# 2   1988     Import                   Finland   World
# 3   1988     Export                   Finland   World
# 4   1988     Import  Fmr Fed. Rep. of Germany   World
# 5   1988     Export  Fmr Fed. Rep. of Germany   World
# 6   1988     Import                    Greece   World
# 7   1988     Export                    Greece   World
# 8   1988     Import                   Iceland   World
# 9   1988     Export                   Iceland   World
# 10  1988     Import                     Japan   World
# 11  1988     Export                     Japan   World
# 12  1988     Import             Rep. of Korea   World
# 13  1988     Export             Rep. of Korea   World
# 14  1988     Import                  Portugal   World
# 15  1988     Export                  Portugal   World
# 16  1988     Import                     India   World
# 17  1988     Export                     India   World
# 18  1988     Import               Switzerland   World
# 19  1988     Export               Switzerland   World
# 20  1988     Import                  Thailand   World
# 21  1989     Import                 Australia   World
# 22  1989     Export                 Australia   World
# 23  1989     Import                Bangladesh   World
# 24  1989     Export                Bangladesh   World
# 25  1989     Import                    Brazil   World
# 26  1989     Export                    Brazil   World
# 27  1989     Import                    Canada   World
# 28  1989     Export                    Canada   World
# 29  1989     Import                    Cyprus   World
# 30  1989     Export                    Cyprus   World
# 31  1989     Import                   Denmark   World
# 32  1989     Export                   Denmark   World
# 33  1989     Import                   Finland   World
# 34  1989     Export                   Finland   World
# 35  1989     Import  Fmr Fed. Rep. of Germany   World
# 27    Rest
# 28    Rest
# 29  Africa
# 30  Africa
# 31  Africa
# 32  Africa
# 33    Rest

# %%
# redo the same groupbys but incorporate africa and west

# group by year and trade flow

SHC_small_grouped_africa_df = SHC_small_df.groupby(['Year', 'Trade Flow', 'Region'], as_index=False).sum()

#export
SHC_small_grouped_export_africa_df = SHC_small_grouped_africa_df[(SHC_small_grouped_africa_df['Trade Flow'] == 'Export') &\
                                                                 (SHC_small_grouped_africa_df['Region'] == 'Africa')]
SHC_small_grouped_export_west_df = SHC_small_grouped_africa_df[(SHC_small_grouped_africa_df['Trade Flow'] == 'Export') &\
                                                               (SHC_small_grouped_africa_df['Region'] == 'West')]
SHC_small_grouped_export_rest_df = SHC_small_grouped_africa_df[(SHC_small_grouped_africa_df['Trade Flow'] == 'Export') &\
                                                               (SHC_small_grouped_africa_df['Region'] == 'Rest')]

#import
SHC_small_grouped_import_africa_df = SHC_small_grouped_africa_df[(SHC_small_grouped_africa_df['Trade Flow'] == 'Import') &\
                                                                 (SHC_small_grouped_africa_df['Region'] == 'Africa')]
SHC_small_grouped_import_west_df = SHC_small_grouped_africa_df[(SHC_small_grouped_africa_df['Trade Flow'] == 'Import') &\
                                                               (SHC_small_grouped_africa_df['Region'] == 'West')]
SHC_small_grouped_import_rest_df = SHC_small_grouped_africa_df[(SHC_small_grouped_africa_df['Trade Flow'] == 'Import') &\
                                                               (SHC_small_grouped_africa_df['Region'] == 'Rest')]

# %%
africa_exports = np.append(np.zeros(2), SHC_small_grouped_export_africa_df['Weight (kg)'])

plt.plot(years, SHC_small_grouped_export_df['Weight (kg)'], label='All')
plt.plot(years, africa_exports, label='Africa')
plt.plot(years, SHC_small_grouped_export_west_df['Weight (kg)'], label='West')
plt.plot(years, SHC_small_grouped_export_rest_df['Weight (kg)'], label='Rest')

plt.legend();

# %%
africa_imports = np.append(np.zeros(2), SHC_small_grouped_import_africa_df['Weight (kg)'])

plt.plot(years, SHC_small_grouped_import_df['Weight (kg)'], label='All')
plt.plot(years, africa_imports, label='Africa')
plt.plot(years, SHC_small_grouped_import_west_df['Weight (kg)'], label='West')
plt.plot(years, SHC_small_grouped_import_rest_df['Weight (kg)'], label='Rest')

plt.legend();

# %%
africa_exports = np.append(np.zeros(2), SHC_small_grouped_export_africa_df['Trade Value (US$)'])

plt.plot(years, SHC_small_grouped_export_df['Trade Value (US$)'], label='All')
plt.plot(years, africa_exports, label='Africa')
plt.plot(years, SHC_small_grouped_export_west_df['Trade Value (US$)'], label='West')
plt.plot(years, SHC_small_grouped_export_rest_df['Trade Value (US$)'], label='Rest')

plt.legend();

# %%
africa_exports = np.append(np.zeros(2), SHC_small_grouped_import_africa_df['Trade Value (US$)'])

plt.plot(years, SHC_small_grouped_import_df['Trade Value (US$)'], label='All')
plt.plot(years, africa_imports, label='Africa')
plt.plot(years, SHC_small_grouped_import_west_df['Trade Value (US$)'], label='West')
plt.plot(years, SHC_small_grouped_import_rest_df['Trade Value (US$)'], label='Rest')

plt.legend();

# %% [markdown]
# ## look at snapshot of 2019 with largest importers and exporters

# %%
SHC_small_2019_df = SHC_small_df[SHC_small_df['Year'] == 2019]

SHC_small_2019_export_df = SHC_small_2019_df[SHC_small_2019_df['Trade Flow'] == 'Export']
SHC_small_2019_import_df = SHC_small_2019_df[SHC_small_2019_df['Trade Flow'] == 'Import']

# %%
SHC_small_2019_export_df.sort_values(['Trade Value (US$)'])
top_exporter_value_2019 = ['USA', 'United Kingdom', 'Germany', 'Rep. of Korea', 'Netherlands', 
                     'Poland', 'Belgium', 'Canada', 'Italy', 'Japan']

top_importer_weight_2019 = ['Pakistan', 'India', 'Malaysia', 'Netherlands', 'Tunisia', 
                            'Ghana', 'Guatemala', 'Poland', 'Philippines', 'Togo']

top_importer_weight_africa_2019 = ['Ghana', 'Togo', 'Benin', 'Madagascar', 'Congo', 
                                   'Rwanda', 'Senegal', "Côte d'Ivoire"]

# %%
SHC_small_2019_import_df.sort_values(['Weight (kg)'])
# Out:
#       Year Trade Flow                Reporter Partner  \
# 500   2019     Import                 Namibia   World
# 526   2019     Import              Seychelles   World
# 417   2019     Import       Brunei Darussalam   World
# 496   2019     Import               Mauritius   World
# 494   2019     Import                   Malta   World
# 1249  2019     Import     Antigua and Barbuda   World
# 563   2019     Import              Uzbekistan   World
# 432   2019     Import                  Cyprus   World
# 504   2019     Import             New Zealand   World
# 1061  2019     Import                   Qatar   World
# 460   2019     Import                 Iceland   World
# 438   2019     Import                 Denmark   World
# 464   2019     Import                 Ireland   World
# 444   2019     Import                 Finland   World
# 547   2019     Import             Switzerland   World
# 506   2019     Import                  Norway   World
# 488   2019     Import        China, Macao SAR   World
# 1307  2019     Import                Suriname   World
# 535   2019     Import                Slovenia   World
# 413   2019     Import                  Brazil   World
# 405   2019     Import                 Armenia   World
# 482   2019     Import  Lao People's Dem. Rep.   World
# 510   2019     Import                    Peru   World
# 557   2019     Import         North Macedonia   World
# 421   2019     Import                 Myanmar   World
# 539   2019     Import                Zimbabwe   World
# 411   2019     Import                Botswana   World
# 427   2019     Import                 Comoros   World
# 466   2019     Import                  Israel   World
# 399   2019     Import              Azerbaijan   World
# 516   2019     Import                Portugal   World
# 543   2019     Import                Eswatini   World
# 533   2019     Import                Viet Nam   World
# 430   2019     Import                 Croatia   World
# 401   2019     Import               Australia   World
# 1286  2019     Import   Sao Tome and Principe   World
# 476   2019     Import              Kazakhstan   World
# 403   2019     Import                 Austria   World
# 452   2019     Import                  Greece   World
# 965   2019     Import         Rep. of Moldova   World
# 409   2019     Import      Bosnia Herzegovina   World
# 565   2019     Import                   Yemen   World
# 462   2019     Import               Indonesia   World
# 446   2019     Import                  France   World
# 472   2019     Import                 Jamaica   World
# 1201  2019     Import                   Egypt   World
# 524   2019     Import                  Serbia   World
# 415   2019     Import                  Belize   World
# 474   2019     Import                   Japan   World
# 442   2019     Import                 Estonia   World
# 780   2019     Import                 Georgia   World
# 529   2019     Import               Singapore   World
# 561   2019     Import                     USA   World
# 545   2019     Import                  Sweden   World
# 786   2019     Import                  Gambia   World
# 566   2019     Import                  Zambia   World
# 559   2019     Import          United Kingdom   World
# 484   2019     Import                  Latvia   World
# 456   2019     Import    China, Hong Kong SAR   World
# 478   2019     Import                  Jordan   World
# 498   2019     Import                 Morocco   World
# 537   2019     Import            South Africa   World
# 541   2019     Import                   Spain   World
# 470   2019     Import           Côte d'Ivoire   World
# 522   2019     Import                 Senegal   World
# 1079  2019     Import                  Rwanda   World
# 429   2019     Import                   Congo   World
# 440   2019     Import             El Salvador   World
# 424   2019     Import                   Chile   World
# 434   2019     Import                 Czechia   World
# 448   2019     Import                 Germany   World
# 419   2019     Import                Bulgaria   World
# 468   2019     Import                   Italy   World
# 520   2019     Import      Russian Federation   World
# 407   2019     Import                 Belgium   World
# 549   2019     Import                Thailand   World
# 480   2019     Import           Rep. of Korea   World
# 490   2019     Import              Madagascar   World
# 458   2019     Import                 Hungary   World
# 486   2019     Import               Lithuania   World
# 555   2019     Import                  Turkey   World
# 436   2019     Import                   Benin   World
# 518   2019     Import                 Romania   World
# 551   2019     Import                    Togo   World
# 512   2019     Import             Philippines   World
# 514   2019     Import                  Poland   World
# 454   2019     Import               Guatemala   World
# 450   2019     Import                   Ghana   World
# 553   2019     Import                 Tunisia   World
# 502   2019     Import             Netherlands   World
# 492   2019     Import                Malaysia   World
# 527   2019     Import                   India   World
# 508   2019     Import                Pakistan   World
# 422   2019     Import                  Canada   World
# 531   2019     Import                Slovakia   World
#
#                                             Commodity  Weight (kg)  \
# 500   Textiles; worn clothing and other worn articles          0.0
# 526   Textiles; worn clothing and other worn articles        139.0
# 417   Textiles; worn clothing and other worn articles       1635.0
# 496   Textiles; worn clothing and other worn articles       2416.0
# 494   Textiles; worn clothing and other worn articles       6379.0
# 1249           Worn clothing and other worn articles.       6647.0
# 563   Textiles; worn clothing and other worn articles      11635.0
# 432   Textiles; worn clothing and other worn articles      15661.0
# 504   Textiles; worn clothing and other worn articles      24153.0
# 1061  Textiles; worn clothing and other worn articles      25110.0
# 460   Textiles; worn clothing and other worn articles      29391.0
# 438   Textiles; worn clothing and other worn articles      43058.0
# 464   Textiles; worn clothing and other worn articles      59056.0
# 444   Textiles; worn clothing and other worn articles      68528.0
# 547   Textiles; worn clothing and other worn articles      89305.0
# 506   Textiles; worn clothing and other worn articles      97279.0
# 488   Textiles; worn clothing and other worn articles     136224.0
# 1307           Worn clothing and other worn articles.     148551.0
# 535   Textiles; worn clothing and other worn articles     164060.0
# 413   Textiles; worn clothing and other worn articles     207339.0
# 405   Textiles; worn clothing and other worn articles     218067.0
# 482   Textiles; worn clothing and other worn articles     230042.0
# 510   Textiles; worn clothing and other worn articles     279631.0
# 557   Textiles; worn clothing and other worn articles     286204.0
# 421   Textiles; worn clothing and other worn articles     345049.0
# 555   Textiles; worn clothing and other worn articles   64670143.0
# 436   Textiles; worn clothing and other worn articles   65472065.0
# 518   Textiles; worn clothing and other worn articles   68282531.0
# 551   Textiles; worn clothing and other worn articles   79319972.0
# 512   Textiles; worn clothing and other worn articles   94638570.0
# 514   Textiles; worn clothing and other worn articles   97783161.0
# 454   Textiles; worn clothing and other worn articles   99053561.0
# 450   Textiles; worn clothing and other worn articles  131689606.0
# 553   Textiles; worn clothing and other worn articles  139187271.0
# 502   Textiles; worn clothing and other worn articles  155700651.0
# 492   Textiles; worn clothing and other worn articles  211612634.0
# 527   Textiles; worn clothing and other worn articles  241972383.0
# 508   Textiles; worn clothing and other worn articles  558466585.0
# 422   Textiles; worn clothing and other worn articles          NaN
# 531   Textiles; worn clothing and other worn articles          NaN
#
#       Trade Value (US$)  Region
# 500              331122  Africa
# 526                 613    Rest
# 417                5510    Rest
# 496                5196    Rest
# 494               80252    Rest
# 1249              17867    Rest
# 563               53712    Rest
# 432               52738    Rest
# 504              481195    West
# 1061              89522    Rest
# 460              381412    West
# 438              424201    West
# 464             1114882    West
# 444              544384    West
# 547              728795    West
# 506              658646    West
# 488              196176    Rest
# 1307              98478    Rest
# 535              507229    Rest
# 413               68085    Rest
# 405             1199743    Rest
# 482             1633864    Rest
# 510              169637    Rest
# 557              331927    Rest
# 421               73669    Rest
# 539              673296  Africa
# 411              355517  Africa
# 427              637795    Rest
# 466              924000    West
# 399             1892539    Rest
# 516             1909802    West
# 543              451299  Africa
# 533             1339268    Rest
# 430             2607474    West
# 401             2464934    West
# 1286            2113143    Rest
# 476             3357261    Rest
# 403             6241725    West
# 452             4529370    West
# 965             6228832    Rest
# 409             3791851    West
# 565              859673    Rest
# 462             6075437    Rest
# 446             7669141    West
# 472             9082073    Rest
# 1201            6607575    Rest
# 524             5561342    West
# 415             3843928    Rest
# 474            49474799    Rest
# 442             8559774    West
# 780            23348731    Rest
# 529             8838684    Rest
# 561            10093454    West
# 545             9989311    West
# 786             1802181  Africa
# 566            23370408  Africa
# 559            72243893    West
# 484            30426106    Rest
# 456             7421582    Rest
# 478            16742389    Rest
# 498             9734917    Rest
# 537             6596485  Africa
# 541            19971448    West
# 470            31483149  Africa
# 522            16913944  Africa
# 1079           20960617  Africa
# 429            11745206  Africa
# 440            45229738    Rest
# 424            65493026    Rest
# 434            22274012    West
# 448            30942983    West
# 419            44030183    West
# 468            45917501    West
# 520           129516165    Rest
# 407            38374692    West
# 549            56628951    Rest
# 480            35404031    Rest
# 490            57316859  Africa
# 458            60738755    West
# 486            65688885    Rest
# 555            32964214    Rest
# 436            24193926  Africa
# 518            54482118    Rest
# 551            27888984  Africa
# 512            25430029    Rest
# 514           119251644    West
# 454           121214942    Rest
# 450            72181080  Africa
# 553            79212447    Rest
# 502           128416337    West
# 492            97304914    Rest
# 527            98930250    Rest
# 508           230376177    Rest
# 422            50602210    West
# 531            35121942    Rest
